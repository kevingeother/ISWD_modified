# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # clone repository

# %%
# ! git clone https://github.com/gkaramanolakis/ISWD
# Out:
# Cloning into 'ISWD'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 49 (delta 14), reused 37 (delta 8), pack-reused 0
# Unpacking objects: 100% (49/49), done.

# %%
# %cd ISWD/data/
# Out:
# /content/drive/MyDrive/ISWD/data

# %% [markdown]
# # download data

# %%
# !bash download_data.sh
# Out:
# downloading datasets
# --2021-07-05 13:51:34--  https://www.dropbox.com/s/u1hmjsuwy8zuhfj/oposum.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u1hmjsuwy8zuhfj/oposum.zip [following]
# --2021-07-05 13:51:34--  https://www.dropbox.com/s/raw/u1hmjsuwy8zuhfj/oposum.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6136e1fc9eb821a71528e21259.dl.dropboxusercontent.com/cd/0/inline/BRueWWdUTkjmJIaN6BhOCLnbSTsCupMGypeb0PXvUOHeY9_mdZFAMedebzUWM2GkvtVpuYPdktc2VX2ohnU8nrBi4mTZoDlfc2VcUWYEXLNgho7xtx42p8jjcYut4T3XpZgDibZLquvXFAFf-8qMSjUV/file# [following]
# ...

# %%
# !bash download_data.sh
# Out:
# downloading datasets
# --2021-07-05 14:23:52--  https://www.dropbox.com/s/u1hmjsuwy8zuhfj/oposum.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u1hmjsuwy8zuhfj/oposum.zip [following]
# --2021-07-05 14:23:52--  https://www.dropbox.com/s/raw/u1hmjsuwy8zuhfj/oposum.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb455246f6e1e0b763341b86dcd.dl.dropboxusercontent.com/cd/0/inline/BRukceTRDYQC1d9FjT73ejIjwf3-YBh6y5ud41dcXpl_d4rDL9FGjYzeUYQ6tWK7q2IscSKle2IcGKICJcT4tkT5-dGnslBmM99Iig60yDvuLMDUpFXFnn6NXtTFFQwlNRF_QKYj6aOopJEacgt28EMK/file# [following]
# ...

# %% [markdown]
# # experiments

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 133kB 4.3MB/s
# ...

# %%
# %cd ../scripts/
# %cd /content/drive/MyDrive/ISWD/scripts/
# Out:
# /content/drive/MyDrive/ISWD/scripts

# %%
# !bash run_5_times.sh pairs --lr 0.0005 --no_seed_weights --logdir $logdir/$(date +'%h%d_%H-%M-%S-%N')_W2V --emb_dropout 0.5 --weight_decay 0.1 --loss SmoothCrossEntropy
# !bash run_experiments.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-07-05 16:44:06,898 INFO [bluetooth] micro_average_f1 (dev): 0.492
# 2021-07-05 16:44:06,899 INFO [bluetooth] micro_average_f1 (test): 0.504
# 2021-07-05 16:44:11,560 DEBUG [boots][9:250/942]	Loss: 1.774653
# 2021-07-05 16:44:13,013 DEBUG [bluetooth][6:50/1399]	Loss: 1.238002
# 2021-07-05 16:44:17,702 DEBUG [boots][9:300/942]	Loss: 1.773032
# 2021-07-05 16:44:19,061 DEBUG [bluetooth][6:100/1399]	Loss: 1.183689
# 2021-07-05 16:44:23,761 DEBUG [boots][9:350/942]	Loss: 1.769693
# 2021-07-05 16:44:25,034 DEBUG [bluetooth][6:150/1399]	Loss: 1.142719
# 2021-07-05 16:44:29,946 DEBUG [boots][9:400/942]	Loss: 1.775489
# 2021-07-05 16:44:31,081 DEBUG [bluetooth][6:200/1399]	Loss: 1.114642
# ...

# %%
# only for BERT, while last time the process stucked in BERT model
# there is some problem here!!!
# !bash run_experiments.sh
# Out:
# 		EXPERIMENT with domain=pairs
# args: Namespace(aspect_seeds='', attention=False, batch_norm=False, batch_size=1024, bert_model='base', cuda_device=0, debug=False, deep_aspect_clf='NO', disable_gpu=False, domain='pairs', emb_dropout=0.5, enable_gpu=True, fix_a_emb=False, fix_w_emb=False, logdir='../experiments/Products/Jul10_23-31-15-405532575_BERT_numseeds30_lr5e-05_CrossEntropy_embdropout0.5_wdecay0.0001_Adam_lr5e-05/v0', loss='CrossEntropy', lr=5e-05, min_len=2, model_type='embedding_based', momentum=0.9, no_pretrained_emb=False, no_seed_weights=True, num_aspects=9, num_epochs=10, num_seeds=30, optimizer='Adam', pretrained_model='', quiet=False, report_every=50, seed=20, swd=0.0, target_metric='micro_average_f1', test_data='', use_bert=True, version=0, weight_decay=0.0001)
# logdir: ../experiments/Products/Jul10_23-31-15-405532575_BERT_numseeds30_lr5e-05_CrossEntropy_embdropout0.5_wdecay0.0001_Adam_lr5e-05/v0
# Running bags_and_cases
# Running keyboards
# ...

# %%
# only for word2vec model -> successful run experiment
# !bash run_experiments.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-07-09 23:16:55,310 DEBUG [tv][19:300/1399]	Loss: 1.431078
# 2021-07-09 23:16:58,757 DEBUG [vacuums][18:1100/1432]	Loss: 1.736104
# 2021-07-09 23:17:01,496 DEBUG [tv][19:350/1399]	Loss: 1.437281
# 2021-07-09 23:17:05,000 DEBUG [vacuums][18:1150/1432]	Loss: 1.797324
# 2021-07-09 23:17:07,547 DEBUG [tv][19:400/1399]	Loss: 1.429655
# 2021-07-09 23:17:11,084 DEBUG [vacuums][18:1200/1432]	Loss: 1.796174
# 2021-07-09 23:17:13,578 DEBUG [tv][19:450/1399]	Loss: 1.418584
# 2021-07-09 23:17:17,224 DEBUG [vacuums][18:1250/1432]	Loss: 1.821655
# 2021-07-09 23:17:19,670 DEBUG [tv][19:500/1399]	Loss: 1.418564
# 2021-07-09 23:17:23,280 DEBUG [vacuums][18:1300/1432]	Loss: 1.857543
# 2021-07-09 23:17:25,771 DEBUG [tv][19:550/1399]	Loss: 1.554624
# 2021-07-09 23:17:29,497 DEBUG [vacuums][18:1350/1432]	Loss: 1.893047
# 2021-07-09 23:17:31,902 DEBUG [tv][19:600/1399]	Loss: 1.629622
# ...
