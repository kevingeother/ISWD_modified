# %%
import os

# %%
# %cd /content/drive/MyDrive/ISWD/experiments/Products/
# Out:
# /content/drive/MyDrive/ISWD/experiments/Products

# %%
base_dir = '/content/drive/MyDrive/ISWD/experiments/Products/'
experiment_list = os.listdir(base_dir)
for folder in experiment_list:
    print(folder)
show_folder = experiment_list[-2]
domain = 'bags_and_cases'
version = 'v0'
show_folder = os.path.join(base_dir, show_folder, version, domain)
print(show_folder)
# Out:
# Jul05_15-56-43-699376143_W2V_numseeds30_lr0.0005_SmoothCrossEntropy_embdropout0.5_wdecay0.1_Adam_lr0.0005
# Jul05_18-35-33-373234043_BERT_numseeds30_lr5e-05_CrossEntropy_embdropout0.5_wdecay0.0001_Adam_lr5e-05
# Jul06_10-42-06-173316981_BERT_numseeds30_lr5e-05_CrossEntropy_embdropout0.5_wdecay0.0001_Adam_lr5e-05
# Jul06_12-04-53-228210425_W2V_numseeds30_lr0.0005_SmoothCrossEntropy_embdropout0.5_wdecay0.1_Adam_lr0.0005
# Jul09_13-02-03-380732417_W2V_numseeds30_lr0.0005_SmoothCrossEntropy_embdropout0.5_wdecay0.1_Adam_lr0.0005
# Jul10_23-31-15-405532575_BERT_numseeds30_lr5e-05_CrossEntropy_embdropout0.5_wdecay0.0001_Adam_lr5e-05
# /content/drive/MyDrive/ISWD/experiments/Products/Jul09_13-02-03-380732417_W2V_numseeds30_lr0.0005_SmoothCrossEntropy_embdropout0.5_wdecay0.1_Adam_lr0.0005/v0/bags_and_cases

# %%
# %cd $show_folder
os.getcwd()
# Out:
# /content/drive/MyDrive/ISWD/experiments/Products/Jul09_13-02-03-380732417_W2V_numseeds30_lr0.0005_SmoothCrossEntropy_embdropout0.5_wdecay0.1_Adam_lr0.0005/v0/bags_and_cases

# %%
# %load_ext tensorboard
# %tensorboard --logdir $show_folder
