# %%
# %cd /content/drive/MyDrive/group-1.3/LeverageJustAFewKeywords
# Out:
# /content/drive/MyDrive/group-1.3/LeverageJustAFewKeywords

# %%
# !pip install mittens transformers tensorboardX
import nltk
nltk.download('words')

# %%
# !python search_param.py
# Out:
# 2021-07-21 02:02:00.298749: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# logging dir: ../experiments/param_search/210721_020204-word2vec
#
# setting: lr=0.0005	dropout=0.1	weight_decay=0.01
# experiment setting: {'domain': 'organic', 'experiment_mode': 'one-time', 'lr': 0.0005, 'batch_size': 512, 'inner_iter': 6, 'epochs': 5, 'gpu': '1', 'student': {'pretrained': 'word2vec', 'wv_path': '../wv/w2v_corpus_wotf1_wostw_tuned.bin', 'wv_prefix': 'w2v_corpus_wotf1_wostw', 'wv_mode': 'tuned', 'pretrained_dim': 300, 'num_aspect': 6, 'freeze_emb': 1, 'dropout': 0.1, 'weight_decay': 0.01}, 'data_dir': '../processed/', 'output_dir': '../experiments/param_search/210721_020204-word2vec/lr0.0005-do0.1-wd0.01', 'general_asp': 0}
#
# INFO:root:loading dataset...
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/group-1.3/experiments/param_search/210715_175058-word2vecb

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/group-1.3/experiments/param_search/210716_010141-word2vec

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/group-1.3/experiments/param_search/210721_020204-word2vec
